# %%
import math

# Constants
gibsons_per_axis = 2**85
gibsons_per_sector = 2**30
km_per_axis = 96056
m_per_axis = km_per_axis * 1000
mm_per_axis = m_per_axis * 1000
mm_per_gibson = mm_per_axis / gibsons_per_axis
mm_per_sector = gibsons_per_sector * mm_per_gibson
m_per_sector = mm_per_sector / 1000

# Corrected calculation
sectors_per_km = 1000 / m_per_sector

def sectors_per_side(pow):
    if pow < 1:
        return 0
    
    # We want POW 128 to result in about 8km side length
    # 96056m / 4km = 24014.0 maximum-sized constructs per axis
    target_sectors = sectors_per_km * 4
    
    # Use a logarithmic scale to calculate the number of sectors
    # sectors = int((target_sectors * math.log(pow + 1) / math.log(129)) ** (0.99999))
    sectors = math.ceil( target_sectors ** (pow/128) )
    
    # Ensure it's always an odd number so the construct can be centered on a sector
    if sectors % 2 == 0:
        sectors += 1
    
    return sectors

def construct_total_sectors(pow):
    side = sectors_per_side(pow)
    return side ** 3

def construct_size_meters(pow):
    side_sectors = sectors_per_side(pow)
    return side_sectors * m_per_sector

# Example usage:
for pow in range(1,129):
    side_sectors = sectors_per_side(pow)
    total_sectors = construct_total_sectors(pow)
    size_meters = construct_size_meters(pow)
    print(f"POW: {pow}")
    print(f"Sectors per side: {side_sectors}")
    print(f"Total sectors: {total_sectors}")
    print(f"Size: {size_meters:.10f} meters per side")
    print(f"Volume: {size_meters**3:.10f} cubic meters")
    print()

# Calculate the size of the smallest construct (POW = 1)
smallest_side = construct_size_meters(1)
print(f"Smallest construct side length: {smallest_side:.2f} meters")
# Out:
# POW: 1
# Sectors per side: 3
# Total sectors: 27
# Size: 0.0000000080 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 2
# Sectors per side: 3
# Total sectors: 27
# Size: 0.0000000080 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 3
# Sectors per side: 3
# Total sectors: 27
# Size: 0.0000000080 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 4
# Sectors per side: 3
# Total sectors: 27
# Size: 0.0000000080 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 5
# Sectors per side: 3
# Total sectors: 27
# Size: 0.0000000080 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 6
# Sectors per side: 5
# Total sectors: 125
# Size: 0.0000000133 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 7
# Sectors per side: 5
# Total sectors: 125
# Size: 0.0000000133 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 8
# Sectors per side: 7
# Total sectors: 343
# Size: 0.0000000187 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 9
# Sectors per side: 9
# Total sectors: 729
# Size: 0.0000000240 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 10
# Sectors per side: 9
# Total sectors: 729
# Size: 0.0000000240 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 11
# Sectors per side: 13
# Total sectors: 2197
# Size: 0.0000000347 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 12
# Sectors per side: 15
# Total sectors: 3375
# Size: 0.0000000400 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 13
# Sectors per side: 19
# Total sectors: 6859
# Size: 0.0000000507 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 14
# Sectors per side: 23
# Total sectors: 12167
# Size: 0.0000000613 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 15
# Sectors per side: 27
# Total sectors: 19683
# Size: 0.0000000720 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 16
# Sectors per side: 35
# Total sectors: 42875
# Size: 0.0000000933 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 17
# Sectors per side: 43
# Total sectors: 79507
# Size: 0.0000001146 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 18
# Sectors per side: 53
# Total sectors: 148877
# Size: 0.0000001413 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 19
# Sectors per side: 65
# Total sectors: 274625
# Size: 0.0000001733 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 20
# Sectors per side: 81
# Total sectors: 531441
# Size: 0.0000002160 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 21
# Sectors per side: 101
# Total sectors: 1030301
# Size: 0.0000002693 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 22
# Sectors per side: 125
# Total sectors: 1953125
# Size: 0.0000003333 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 23
# Sectors per side: 155
# Total sectors: 3723875
# Size: 0.0000004132 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 24
# Sectors per side: 193
# Total sectors: 7189057
# Size: 0.0000005146 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 25
# Sectors per side: 239
# Total sectors: 13651919
# Size: 0.0000006372 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 26
# Sectors per side: 299
# Total sectors: 26730899
# Size: 0.0000007972 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 27
# Sectors per side: 371
# Total sectors: 51064811
# Size: 0.0000009891 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 28
# Sectors per side: 461
# Total sectors: 97972181
# Size: 0.0000012291 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 29
# Sectors per side: 575
# Total sectors: 190109375
# Size: 0.0000015330 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 30
# Sectors per side: 715
# Total sectors: 365525875
# Size: 0.0000019063 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 31
# Sectors per side: 891
# Total sectors: 707347971
# Size: 0.0000023755 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 32
# Sectors per side: 1107
# Total sectors: 1356572043
# Size: 0.0000029514 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 33
# Sectors per side: 1379
# Total sectors: 2622362939
# Size: 0.0000036765 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 34
# Sectors per side: 1717
# Total sectors: 5061868813
# Size: 0.0000045777 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 35
# Sectors per side: 2137
# Total sectors: 9759185353
# Size: 0.0000056974 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 36
# Sectors per side: 2659
# Total sectors: 18799877179
# Size: 0.0000070891 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 37
# Sectors per side: 3309
# Total sectors: 36231832629
# Size: 0.0000088221 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 38
# Sectors per side: 4121
# Total sectors: 69985463561
# Size: 0.0000109870 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 39
# Sectors per side: 5129
# Total sectors: 134926761689
# Size: 0.0000136744 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 40
# Sectors per side: 6385
# Total sectors: 260305116625
# Size: 0.0000170230 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 41
# Sectors per side: 7947
# Total sectors: 501891267123
# Size: 0.0000211874 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 42
# Sectors per side: 9893
# Total sectors: 968242244957
# Size: 0.0000263756 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 43
# Sectors per side: 12317
# Total sectors: 1868593459013
# Size: 0.0000328382 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 44
# Sectors per side: 15331
# Total sectors: 3603391509691
# Size: 0.0000408738 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 45
# Sectors per side: 19085
# Total sectors: 6951467439125
# Size: 0.0000508823 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 46
# Sectors per side: 23759
# Total sectors: 13411719834479
# Size: 0.0000633436 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 47
# Sectors per side: 29577
# Total sectors: 25873927923033
# Size: 0.0000788549 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 48
# Sectors per side: 36819
# Total sectors: 49913263541259
# Size: 0.0000981628 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 49
# Sectors per side: 45835
# Total sectors: 96292332557875
# Size: 0.0001222002 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 50
# Sectors per side: 57059
# Total sectors: 185768668456379
# Size: 0.0001521244 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 51
# Sectors per side: 71033
# Total sectors: 358410290992937
# Size: 0.0001893803 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 52
# Sectors per side: 88427
# Total sectors: 691440276710483
# Size: 0.0002357543 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 53
# Sectors per side: 110079
# Total sectors: 1333869760023039
# Size: 0.0002934805 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 54
# Sectors per side: 137035
# Total sectors: 2573324248517875
# Size: 0.0003653476 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 55
# Sectors per side: 170591
# Total sectors: 4964418039735071
# Size: 0.0004548109 meters per side
# Volume: 0.0000000001 cubic meters
#
# POW: 56
# Sectors per side: 212365
# Total sectors: 9577426459727125
# Size: 0.0005661841 meters per side
# Volume: 0.0000000002 cubic meters
#
# POW: 57
# Sectors per side: 264369
# Total sectors: 18477005361755409
# Size: 0.0007048314 meters per side
# Volume: 0.0000000004 cubic meters
#
# POW: 58
# Sectors per side: 329105
# Total sectors: 35645395797832625
# Size: 0.0008774234 meters per side
# Volume: 0.0000000007 cubic meters
#
# POW: 59
# Sectors per side: 409695
# Total sectors: 68767302892377375
# Size: 0.0010922836 meters per side
# Volume: 0.0000000013 cubic meters
#
# POW: 60
# Sectors per side: 510021
# Total sectors: 132667386974739261
# Size: 0.0013597617 meters per side
# Volume: 0.0000000025 cubic meters
#
# POW: 61
# Sectors per side: 634913
# Total sectors: 255942647693286497
# Size: 0.0016927349 meters per side
# Volume: 0.0000000049 cubic meters
#
# POW: 62
# Sectors per side: 790387
# Total sectors: 493763935110490603
# Size: 0.0021072425 meters per side
# Volume: 0.0000000094 cubic meters
#
# POW: 63
# Sectors per side: 983935
# Total sectors: 952575106551925375
# Size: 0.0026232588 meters per side
# Volume: 0.0000000181 cubic meters
#
# POW: 64
# Sectors per side: 1224879
# Total sectors: 1837720951928903439
# Size: 0.0032656371 meters per side
# Volume: 0.0000000348 cubic meters
#
# POW: 65
# Sectors per side: 1524823
# Total sectors: 3545343361449629767
# Size: 0.0040653147 meters per side
# Volume: 0.0000000672 cubic meters
#
# POW: 66
# Sectors per side: 1898217
# Total sectors: 6839708225138984313
# Size: 0.0050608165 meters per side
# Volume: 0.0000001296 cubic meters
#
# POW: 67
# Sectors per side: 2363045
# Total sectors: 13195199970170316125
# Size: 0.0063000896 meters per side
# Volume: 0.0000002501 cubic meters
#
# POW: 68
# Sectors per side: 2941701
# Total sectors: 25456317815518495101
# Size: 0.0078428384 meters per side
# Volume: 0.0000004824 cubic meters
#
# POW: 69
# Sectors per side: 3662057
# Total sectors: 49110606715417699193
# Size: 0.0097633720 meters per side
# Volume: 0.0000009307 cubic meters
#
# POW: 70
# Sectors per side: 4558809
# Total sectors: 94744539870330669129
# Size: 0.0121541931 meters per side
# Volume: 0.0000017955 cubic meters
#
# POW: 71
# Sectors per side: 5675157
# Total sectors: 182782091144028094893
# Size: 0.0151304769 meters per side
# Volume: 0.0000034638 cubic meters
#
# POW: 72
# Sectors per side: 7064871
# Total sectors: 352624683172628848311
# Size: 0.0188355789 meters per side
# Volume: 0.0000066825 cubic meters
#
# POW: 73
# Sectors per side: 8794895
# Total sectors: 680286694278018467375
# Size: 0.0234479778 meters per side
# Volume: 0.0000128919 cubic meters
#
# POW: 74
# Sectors per side: 10948563
# Total sectors: 1312415543153764289547
# Size: 0.0291898496 meters per side
# Volume: 0.0000248711 cubic meters
#
# POW: 75
# Sectors per side: 13629615
# Total sectors: 2531924580741363183375
# Size: 0.0363377744 meters per side
# Volume: 0.0000479816 cubic meters
#
# POW: 76
# Sectors per side: 16967193
# Total sectors: 4884611186951549538057
# Size: 0.0452360563 meters per side
# Volume: 0.0000925666 cubic meters
#
# POW: 77
# Sectors per side: 21122069
# Total sectors: 9423437858898673854509
# Size: 0.0563133279 meters per side
# Volume: 0.0001785803 cubic meters
#
# POW: 78
# Sectors per side: 26294379
# Total sectors: 18179785524248475801939
# Size: 0.0701031696 meters per side
# Volume: 0.0003445188 cubic meters
#
# POW: 79
# Sectors per side: 32733267
# Total sectors: 35072607814718016545163
# Size: 0.0872698218 meters per side
# Volume: 0.0006646489 cubic meters
#
# POW: 80
# Sectors per side: 40748891
# Total sectors: 67662397333914088311971
# Size: 0.1086401933 meters per side
# Volume: 0.0012822467 cubic meters
#
# POW: 81
# Sectors per side: 50727357
# Total sectors: 130534919537732920768293
# Size: 0.1352436775 meters per side
# Volume: 0.0024737221 cubic meters
#
# POW: 82
# Sectors per side: 63149321
# Total sectors: 251829182564211404403161
# Size: 0.1683617462 meters per side
# Volume: 0.0047723278 cubic meters
#
# POW: 83
# Sectors per side: 78613137
# Total sectors: 485831176278372523762353
# Size: 0.2095896647 meters per side
# Volume: 0.0092068187 cubic meters
#
# POW: 84
# Sectors per side: 97863689
# Total sectors: 937270067657731713751769
# Size: 0.2609133607 meters per side
# Volume: 0.0177618810 cubic meters
#
# POW: 85
# Sectors per side: 121828255
# Total sectors: 1808190032856429373681375
# Size: 0.3248050401 meters per side
# Volume: 0.0342663841 cubic meters
#
# POW: 86
# Sectors per side: 151661195
# Total sectors: 3488377052654550520989875
# Size: 0.4043423304 meters per side
# Volume: 0.0661070275 cubic meters
#
# POW: 87
# Sectors per side: 188799533
# Total sectors: 6729809132862085507752437
# Size: 0.5033564660 meters per side
# Volume: 0.1275342861 cubic meters
#
# POW: 88
# Sectors per side: 235032199
# Total sectors: 12983210300285181842576599
# Size: 0.6266168947 meters per side
# Volume: 0.2460403296 cubic meters
#
# POW: 89
# Sectors per side: 292586181
# Total sectors: 25047329612520908263767741
# Size: 0.7800609659 meters per side
# Volume: 0.4746632836 cubic meters
#
# POW: 90
# Sectors per side: 364233811
# Total sectors: 48321540776551305749390731
# Size: 0.9710799650 meters per side
# Volume: 0.9157248126 cubic meters
#
# POW: 91
# Sectors per side: 453426299
# Total sectors: 93222365224152702212208899
# Size: 1.2088751271 meters per side
# Volume: 1.7666248127 cubic meters
#
# POW: 92
# Sectors per side: 564459975
# Total sectors: 179845450708405188362484375
# Size: 1.5049008528 meters per side
# Volume: 3.4081889566 cubic meters
#
# POW: 93
# Sectors per side: 702683249
# Total sectors: 346959514981835359444487249
# Size: 1.8734164821 meters per side
# Volume: 6.5751098106 cubic meters
#
# POW: 94
# Sectors per side: 874754223
# Total sectors: 669357514504904551140087567
# Size: 2.3321731114 meters per side
# Volume: 12.6847628337 cubic meters
#
# POW: 95
# Sectors per side: 1088961421
# Total sectors: 1291330718923569881707421461
# Size: 2.9032686881 meters per side
# Volume: 24.4715619896 cubic meters
#
# POW: 96
# Sectors per side: 1355623041
# Total sectors: 2491247209749983533273857921
# Size: 3.6142124523 meters per side
# Volume: 47.2107645482 cubic meters
#
# POW: 97
# Sectors per side: 1687583961
# Total sectors: 4806137233762648828893732681
# Size: 4.4992499992 meters per side
# Volume: 91.0794450432 cubic meters
#
# POW: 98
# Sectors per side: 2100834477
# Total sectors: 9272044518307829846722089333
# Size: 5.6010128902 meters per side
# Volume: 175.7113099498 cubic meters
#
# POW: 99
# Sectors per side: 2615280547
# Total sectors: 17887714323002733600504227323
# Size: 6.9725721925 meters per side
# Volume: 338.9838896370 cubic meters
#
# POW: 100
# Sectors per side: 3255702633
# Total sectors: 34509144438862800794985670137
# Size: 8.6799948372 meters per side
# Volume: 653.9708650694 cubic meters
#
# POW: 101
# Sectors per side: 4052949365
# Total sectors: 66575361593753224489535202125
# Size: 10.8055260352 meters per side
# Volume: 1261.6466597980 cubic meters
#
# POW: 102
# Sectors per side: 5045423497
# Total sectors: 128437805408228074914931184473
# Size: 13.4515509683 meters per side
# Volume: 2433.9804442050 cubic meters
#
# POW: 103
# Sectors per side: 6280931727
# Total sectors: 247783405822449662019666737583
# Size: 16.7455265756 meters per side
# Volume: 4695.6576551076 cubic meters
#
# POW: 104
# Sectors per side: 7818987519
# Total sectors: 478026045118911897698744719359
# Size: 20.8461210828 meters per side
# Volume: 9058.9063083257 cubic meters
#
# POW: 105
# Sectors per side: 9733677821
# Total sectors: 922212281823661979456016658661
# Size: 25.9508569293 meters per side
# Volume: 17476.5261071698 cubic meters
#
# POW: 106
# Sectors per side: 12117231761
# Total sectors: 1779140490189932555525405564081
# Size: 32.3056252314 meters per side
# Volume: 33715.8763095638 cubic meters
#
# POW: 107
# Sectors per side: 15084463267
# Total sectors: 3432334339745872689609436455163
# Size: 40.2165302053 meters per side
# Volume: 65044.9813772638 cubic meters
#
# POW: 108
# Sectors per side: 18778301561
# Total sectors: 6621691255318596090307666621481
# Size: 50.0646339592 meters per side
# Volume: 125485.3815960360 cubic meters
#
# POW: 109
# Sectors per side: 23376675937
# Total sectors: 12774628205139012749225616881953
# Size: 62.3243119281 meters per side
# Volume: 242087.5624156876 cubic meters
#
# POW: 110
# Sectors per side: 29101086493
# Total sectors: 24644931262468045078152357465157
# Size: 77.5861032135 meters per side
# Volume: 467037.5716166010 cubic meters
#
# POW: 111
# Sectors per side: 36227273599
# Total sectors: 47545230047531506893265166940799
# Size: 96.5851563402 meters per side
# Volume: 901013.2163431331 cubic meters
#
# POW: 112
# Sectors per side: 45098500111
# Total sectors: 91724698936701902516225856867631
# Size: 120.2366408288 meters per side
# Volume: 1738243.0566524134 cubic meters
#
# POW: 113
# Sectors per side: 56142086065
# Total sectors: 176956140227595087027779160324625
# Size: 149.6798301709 meters per side
# Volume: 3353434.6326379776 cubic meters
#
# POW: 114
# Sectors per side: 69889992351
# Total sectors: 341385427581818408504386148419551
# Size: 186.3329797477 meters per side
# Volume: 6469477.2075067442 cubic meters
#
# POW: 115
# Sectors per side: 87004444847
# Total sectors: 658603934297406342092252680433423
# Size: 231.9616430664 meters per side
# Volume: 12480975.4531486742 cubic meters
#
# POW: 116
# Sectors per side: 108309833335
# Total sectors: 1270584820730630928688078507870375
# Size: 288.7637171275 meters per side
# Volume: 24078413.6456756145 cubic meters
#
# POW: 117
# Sectors per side: 134832421695
# Total sectors: 2451224024875873411960539281277375
# Size: 359.4753133589 meters per side
# Volume: 46452299.0092386380 cubic meters
#
# POW: 118
# Sectors per side: 167849782243
# Total sectors: 4728924131638333181993098342302907
# Size: 447.5025539889 meters per side
# Volume: 89616206.2404686809 cubic meters
#
# POW: 119
# Sectors per side: 208952335387
# Total sectors: 9123084310501264474645655064805603
# Size: 557.0856422813 meters per side
# Volume: 172888416.5531783700 cubic meters
#
# POW: 120
# Sectors per side: 260119958933
# Total sectors: 17600338897652199581491616606552237
# Size: 693.5031098073 meters per side
# Volume: 333537937.3083105087 cubic meters
#
# POW: 121
# Sectors per side: 323817357245
# Total sectors: 33954737100702121591741808591481125
# Size: 863.3260791681 meters per side
# Volume: 643464483.2847434282 cubic meters
#
# POW: 122
# Sectors per side: 403112784131
# Total sectors: 65505793854023968852382407268920091
# Size: 1074.7347898434 meters per side
# Volume: 1241377651.3547170162 cubic meters
#
# POW: 123
# Sectors per side: 501825838219
# Total sectors: 126374385278822793493236953367457459
# Size: 1337.9126339020 meters per side
# Volume: 2394877282.7395358086 cubic meters
#
# POW: 124
# Sectors per side: 624711450039
# Total sectors: 243802636604953130680524550846409319
# Size: 1665.5366820425 meters per side
# Volume: 4620219473.9779119492 cubic meters
#
# POW: 125
# Sectors per side: 777688923305
# Total sectors: 470346308589297911195383438249597625
# Size: 2073.3883281661 meters per side
# Volume: 8913370276.5450325012 cubic meters
#
# POW: 126
# Sectors per side: 968127063131
# Total sectors: 907396462497031880893692478403677091
# Size: 2581.1134667406 meters per side
# Volume: 17195756637.5321235657 cubic meters
#
# POW: 127
# Sectors per side: 1205199125613
# Total sectors: 1750557674450944762365215519611721397
# Size: 3213.1688201787 meters per side
# Volume: 33174213250.7168502808 cubic meters
#
# POW: 128
# Sectors per side: 1500324686391
# Total sectors: 3377192107569115098731085624128874471
# Size: 4000.0000000033 meters per side
# Volume: 64000000000.1572494507 cubic meters
#
# Smallest construct side length: 0.00 meters
