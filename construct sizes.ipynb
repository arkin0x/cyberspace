# %%
import math

# Constants
gibsons_per_axis = 2**85
gibsons_per_sector = 2**30
km_per_axis = 96056
m_per_axis = km_per_axis * 1000
mm_per_axis = m_per_axis * 1000
mm_per_gibson = mm_per_axis / gibsons_per_axis
mm_per_sector = gibsons_per_sector * mm_per_gibson
m_per_sector = mm_per_sector / 1000

# Corrected calculation
sectors_per_km = 1000 / m_per_sector

def sectors_per_side(pow):
    if pow < 1:
        return 0
    
    # We want POW 128 to result in about 8km side length
    # 96056m / 4km = 24014.0 maximum-sized constructs per axis
    target_sectors = sectors_per_km * 4
    
    # Use a logarithmic scale to calculate the number of sectors
    # sectors = int((target_sectors * math.log(pow + 1) / math.log(129)) ** (0.99999))
    sectors = math.ceil( target_sectors ** (pow/128) )
    
    # Ensure it's always an odd number so the construct can be centered on a sector
    if sectors % 2 == 0:
        sectors += 1
    
    return sectors

def construct_total_sectors(pow):
    side = sectors_per_side(pow)
    return side ** 3

def construct_size_meters(pow):
    side_sectors = sectors_per_side(pow)
    return side_sectors * m_per_sector

# Example usage:
for pow in range(1,129):
    side_sectors = sectors_per_side(pow)
    total_sectors = construct_total_sectors(pow)
    size_meters = construct_size_meters(pow)
    print(f"POW: {pow}")
    print(f"Sectors per side: {side_sectors}")
    print(f"Total sectors: {total_sectors}")
    print(f"Size: {size_meters:.10f} meters per side")
    print(f"Volume: {size_meters**3:.10f} cubic meters")
    print()

# Calculate the size of the smallest construct (POW = 1)
smallest_side = construct_size_meters(1)
print(f"Smallest construct side length: {smallest_side:.2f} meters")
# Out:
# POW: 1
# Sectors per side: 3
# Total sectors: 27
# Size: 0.0000000080 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 2
# Sectors per side: 3
# Total sectors: 27
# Size: 0.0000000080 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 3
# Sectors per side: 3
# Total sectors: 27
# Size: 0.0000000080 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 4
# Sectors per side: 3
# Total sectors: 27
# Size: 0.0000000080 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 5
# Sectors per side: 5
# Total sectors: 125
# Size: 0.0000000133 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 6
# Sectors per side: 5
# Total sectors: 125
# Size: 0.0000000133 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 7
# Sectors per side: 5
# Total sectors: 125
# Size: 0.0000000133 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 8
# Sectors per side: 7
# Total sectors: 343
# Size: 0.0000000187 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 9
# Sectors per side: 9
# Total sectors: 729
# Size: 0.0000000240 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 10
# Sectors per side: 11
# Total sectors: 1331
# Size: 0.0000000293 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 11
# Sectors per side: 13
# Total sectors: 2197
# Size: 0.0000000347 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 12
# Sectors per side: 15
# Total sectors: 3375
# Size: 0.0000000400 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 13
# Sectors per side: 19
# Total sectors: 6859
# Size: 0.0000000507 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 14
# Sectors per side: 25
# Total sectors: 15625
# Size: 0.0000000667 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 15
# Sectors per side: 29
# Total sectors: 24389
# Size: 0.0000000773 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 16
# Sectors per side: 37
# Total sectors: 50653
# Size: 0.0000000986 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 17
# Sectors per side: 47
# Total sectors: 103823
# Size: 0.0000001253 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 18
# Sectors per side: 57
# Total sectors: 185193
# Size: 0.0000001520 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 19
# Sectors per side: 73
# Total sectors: 389017
# Size: 0.0000001946 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 20
# Sectors per side: 91
# Total sectors: 753571
# Size: 0.0000002426 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 21
# Sectors per side: 113
# Total sectors: 1442897
# Size: 0.0000003013 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 22
# Sectors per side: 141
# Total sectors: 2803221
# Size: 0.0000003759 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 23
# Sectors per side: 175
# Total sectors: 5359375
# Size: 0.0000004666 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 24
# Sectors per side: 219
# Total sectors: 10503459
# Size: 0.0000005839 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 25
# Sectors per side: 275
# Total sectors: 20796875
# Size: 0.0000007332 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 26
# Sectors per side: 343
# Total sectors: 40353607
# Size: 0.0000009145 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 27
# Sectors per side: 429
# Total sectors: 78953589
# Size: 0.0000011438 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 28
# Sectors per side: 537
# Total sectors: 154854153
# Size: 0.0000014317 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 29
# Sectors per side: 673
# Total sectors: 304821217
# Size: 0.0000017943 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 30
# Sectors per side: 841
# Total sectors: 594823321
# Size: 0.0000022422 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 31
# Sectors per side: 1053
# Total sectors: 1167575877
# Size: 0.0000028074 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 32
# Sectors per side: 1317
# Total sectors: 2284322013
# Size: 0.0000035112 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 33
# Sectors per side: 1649
# Total sectors: 4483962449
# Size: 0.0000043964 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 34
# Sectors per side: 2063
# Total sectors: 8780064047
# Size: 0.0000055001 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 35
# Sectors per side: 2581
# Total sectors: 17193488941
# Size: 0.0000068812 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 36
# Sectors per side: 3231
# Total sectors: 33729575391
# Size: 0.0000086141 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 37
# Sectors per side: 4043
# Total sectors: 66086267507
# Size: 0.0000107790 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 38
# Sectors per side: 5061
# Total sectors: 129631041981
# Size: 0.0000134931 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 39
# Sectors per side: 6335
# Total sectors: 254237645375
# Size: 0.0000168897 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 40
# Sectors per side: 7929
# Total sectors: 498488626089
# Size: 0.0000211394 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 41
# Sectors per side: 9923
# Total sectors: 977077413467
# Size: 0.0000264556 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 42
# Sectors per side: 12419
# Total sectors: 1915401756059
# Size: 0.0000331102 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 43
# Sectors per side: 15545
# Total sectors: 3756403003625
# Size: 0.0000414444 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 44
# Sectors per side: 19457
# Total sectors: 7365930836993
# Size: 0.0000518741 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 45
# Sectors per side: 24353
# Total sectors: 14442999834977
# Size: 0.0000649273 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 46
# Sectors per side: 30479
# Total sectors: 28314059592239
# Size: 0.0000812597 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 47
# Sectors per side: 38149
# Total sectors: 55520002221949
# Size: 0.0001017087 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 48
# Sectors per side: 47749
# Total sectors: 108866144330749
# Size: 0.0001273031 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 49
# Sectors per side: 59765
# Total sectors: 213471927522125
# Size: 0.0001593388 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 50
# Sectors per side: 74803
# Total sectors: 418559349379627
# Size: 0.0001994315 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 51
# Sectors per side: 93625
# Total sectors: 820683103515625
# Size: 0.0002496126 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 52
# Sectors per side: 117185
# Total sectors: 1609222414306625
# Size: 0.0003124257 meters per side
# Volume: 0.0000000000 cubic meters
#
# POW: 53
# Sectors per side: 146673
# Total sectors: 3155371691723217
# Size: 0.0003910434 meters per side
# Volume: 0.0000000001 cubic meters
#
# POW: 54
# Sectors per side: 183581
# Total sectors: 6187043844111941
# Size: 0.0004894434 meters per side
# Volume: 0.0000000001 cubic meters
#
# POW: 55
# Sectors per side: 229777
# Total sectors: 12131644201920433
# Size: 0.0006126061 meters per side
# Volume: 0.0000000002 cubic meters
#
# POW: 56
# Sectors per side: 287597
# Total sectors: 23787732959925173
# Size: 0.0007667594 meters per side
# Volume: 0.0000000005 cubic meters
#
# POW: 57
# Sectors per side: 359965
# Total sectors: 46642393322957125
# Size: 0.0009596989 meters per side
# Volume: 0.0000000009 cubic meters
#
# POW: 58
# Sectors per side: 450545
# Total sectors: 91456488645628625
# Size: 0.0012011933 meters per side
# Volume: 0.0000000017 cubic meters
#
# POW: 59
# Sectors per side: 563919
# Total sectors: 179328857772680559
# Size: 0.0015034586 meters per side
# Volume: 0.0000000034 cubic meters
#
# POW: 60
# Sectors per side: 705823
# Total sectors: 351631212833276767
# Size: 0.0018817873 meters per side
# Volume: 0.0000000067 cubic meters
#
# POW: 61
# Sectors per side: 883433
# Total sectors: 689478699750543737
# Size: 0.0023553115 meters per side
# Volume: 0.0000000131 cubic meters
#
# POW: 62
# Sectors per side: 1105737
# Total sectors: 1351934112280550553
# Size: 0.0029479939 meters per side
# Volume: 0.0000000256 cubic meters
#
# POW: 63
# Sectors per side: 1383979
# Total sectors: 2650870432103022739
# Size: 0.0036898120 meters per side
# Volume: 0.0000000502 cubic meters
#
# POW: 64
# Sectors per side: 1732239
# Total sectors: 5197846338622367919
# Size: 0.0046183043 meters per side
# Volume: 0.0000000985 cubic meters
#
# POW: 65
# Sectors per side: 2168133
# Total sectors: 10191961136427608637
# Size: 0.0057804368 meters per side
# Volume: 0.0000001931 cubic meters
#
# POW: 66
# Sectors per side: 2713715
# Total sectors: 19984473249730800875
# Size: 0.0072350073 meters per side
# Volume: 0.0000003787 cubic meters
#
# POW: 67
# Sectors per side: 3396585
# Total sectors: 39185686714868501625
# Size: 0.0090555998 meters per side
# Volume: 0.0000007426 cubic meters
#
# POW: 68
# Sectors per side: 4251289
# Total sectors: 76835493874034450569
# Size: 0.0113343173 meters per side
# Volume: 0.0000014561 cubic meters
#
# POW: 69
# Sectors per side: 5321069
# Total sectors: 150659552036487171509
# Size: 0.0141864466 meters per side
# Volume: 0.0000028551 cubic meters
#
# POW: 70
# Sectors per side: 6660045
# Total sectors: 295414284046459591125
# Size: 0.0177562765 meters per side
# Volume: 0.0000055983 cubic meters
#
# POW: 71
# Sectors per side: 8335955
# Total sectors: 579250056105681108875
# Size: 0.0222244027 meters per side
# Volume: 0.0000109772 cubic meters
#
# POW: 72
# Sectors per side: 10433587
# Total sectors: 1135797543949996393003
# Size: 0.0278168775 meters per side
# Volume: 0.0000215241 cubic meters
#
# POW: 73
# Sectors per side: 13059059
# Total sectors: 2227079149649512342379
# Size: 0.0348166210 meters per side
# Volume: 0.0000422046 cubic meters
#
# POW: 74
# Sectors per side: 16345195
# Total sectors: 4366870553519188289875
# Size: 0.0435777539 meters per side
# Volume: 0.0000827551 cubic meters
#
# POW: 75
# Sectors per side: 20458243
# Total sectors: 8562587023734043674907
# Size: 0.0545435083 meters per side
# Volume: 0.0001622666 cubic meters
#
# POW: 76
# Sectors per side: 25606285
# Total sectors: 16789575846742345199125
# Size: 0.0682686494 meters per side
# Volume: 0.0003181734 cubic meters
#
# POW: 77
# Sectors per side: 32049763
# Total sectors: 32921109789423136037947
# Size: 0.0854475389 meters per side
# Volume: 0.0006238766 cubic meters
#
# POW: 78
# Sectors per side: 40114655
# Total sectors: 64551922999511147561375
# Size: 0.1069492634 meters per side
# Volume: 0.0012233012 cubic meters
#
# POW: 79
# Sectors per side: 50208969
# Total sectors: 126573826831711419517209
# Size: 0.1338616086 meters per side
# Volume: 0.0023986568 cubic meters
#
# POW: 80
# Sectors per side: 62843381
# Total sectors: 248186769802821920475341
# Size: 0.1675460827 meters per side
# Volume: 0.0047033017 cubic meters
#
# POW: 81
# Sectors per side: 78657073
# Total sectors: 486646208396929620848017
# Size: 0.2097068020 meters per side
# Volume: 0.0092222640 cubic meters
#
# POW: 82
# Sectors per side: 98450069
# Total sectors: 954219032453723661678509
# Size: 0.2624767023 meters per side
# Volume: 0.0180830750 cubic meters
#
# POW: 83
# Sectors per side: 123223707
# Total sectors: 1871038867343639242374243
# Size: 0.3285254402 meters per side
# Volume: 0.0354574107 cubic meters
#
# POW: 84
# Sectors per side: 154231297
# Total sectors: 3668745047545617364035073
# Size: 0.4111944525 meters per side
# Volume: 0.0695251190 cubic meters
#
# POW: 85
# Sectors per side: 193041531
# Total sectors: 7193698963401707082924291
# Size: 0.5146660126 meters per side
# Volume: 0.1363253019 cubic meters
#
# POW: 86
# Sectors per side: 241617841
# Total sectors: 14105451694193327281954321
# Size: 0.6441748061 meters per side
# Volume: 0.2673075382 cubic meters
#
# POW: 87
# Sectors per side: 302417725
# Total sectors: 27658060737313695762953125
# Size: 0.8062727428 meters per side
# Volume: 0.5241383465 cubic meters
#
# POW: 88
# Sectors per side: 378517085
# Total sectors: 54232104863078036051589125
# Size: 1.0091604529 meters per side
# Volume: 1.0277338691 cubic meters
#
# POW: 89
# Sectors per side: 473765825
# Total sectors: 106338661459795676345890625
# Size: 1.2631021253 meters per side
# Volume: 2.0151872078 cubic meters
#
# POW: 90
# Sectors per side: 592982633
# Total sectors: 208509536272014735623430137
# Size: 1.5809448138 meters per side
# Volume: 3.9513921318 cubic meters
#
# POW: 91
# Sectors per side: 742198749
# Total sectors: 408846848070752109268783749
# Size: 1.9787683446 meters per side
# Volume: 7.7479152631 cubic meters
#
# POW: 92
# Sectors per side: 928963097
# Total sectors: 801669546389304881218513673
# Size: 2.4766988251 meters per side
# Volume: 15.1921624044 cubic meters
#
# POW: 93
# Sectors per side: 1162724185
# Total sectors: 1571918835944699404373031625
# Size: 3.0999268240 meters per side
# Volume: 29.7888903848 cubic meters
#
# POW: 94
# Sectors per side: 1455308113
# Total sectors: 3082228638185979939380998897
# Size: 3.8799817831 meters per side
# Volume: 58.4102492725 cubic meters
#
# POW: 95
# Sectors per side: 1821516855
# Total sectors: 6043653857632091444466726375
# Size: 4.8563270911 meters per side
# Volume: 114.5311947231 cubic meters
#
# POW: 96
# Sectors per side: 2279877111
# Total sectors: 11850435624761015402051918631
# Size: 6.0783565896 meters per side
# Volume: 224.5735083553 cubic meters
#
# POW: 97
# Sectors per side: 2853577569
# Total sectors: 23236410889846375907816511009
# Size: 7.6078933977 meters per side
# Volume: 440.3451890169 cubic meters
#
# POW: 98
# Sectors per side: 3571642043
# Total sectors: 45562104903348389425054253507
# Size: 9.5223176034 meters per side
# Volume: 863.4316973814 cubic meters
#
# POW: 99
# Sectors per side: 4470397799
# Total sectors: 89338470268232884740028673399
# Size: 11.9184809516 meters per side
# Volume: 1693.0224621709 cubic meters
#
# POW: 100
# Sectors per side: 5595313373
# Total sectors: 175175451032041013265270026117
# Size: 14.9176066321 meters per side
# Volume: 3319.6894073485 cubic meters
#
# POW: 101
# Sectors per side: 7003298845
# Total sectors: 343485158780844293880306701125
# Size: 18.6714220156 meters per side
# Volume: 6509.2684874984 cubic meters
#
# POW: 102
# Sectors per side: 8765584953
# Total sectors: 673507923560078899410806691177
# Size: 23.3698346298 meters per side
# Volume: 12763.4158007604 cubic meters
#
# POW: 103
# Sectors per side: 10971326693
# Total sectors: 1320618697216628379097157334557
# Size: 29.2505396799 meters per side
# Volume: 25026.5883402495 cubic meters
#
# POW: 104
# Sectors per side: 13732113723
# Total sectors: 2589477693196732329122428064067
# Size: 36.6110451893 meters per side
# Volume: 49072.2964777645 cubic meters
#
# POW: 105
# Sectors per side: 17187615733
# Total sectors: 5077464627348351082231596037837
# Size: 45.8237230619 meters per side
# Volume: 96221.2766702797 cubic meters
#
# POW: 106
# Sectors per side: 21512648421
# Total sectors: 9955925518719996357076559122461
# Size: 57.3546476070 meters per side
# Volume: 188671.3023436157 cubic meters
#
# POW: 107
# Sectors per side: 26926017505
# Total sectors: 19521643224673384546033420062625
# Size: 71.7871744677 meters per side
# Volume: 369947.9113379389 cubic meters
#
# POW: 108
# Sectors per side: 33701588223
# Total sectors: 38278164441960543517157556045567
# Size: 89.8514528988 meters per side
# Volume: 725396.2600471813 cubic meters
#
# POW: 109
# Sectors per side: 42182140325
# Total sectors: 75056072704770009315575646828125
# Size: 112.4613644171 meters per side
# Volume: 1422361.6839418353 cubic meters
#
# POW: 110
# Sectors per side: 52796709477
# Total sectors: 147170433360126003308280825714333
# Size: 140.7607565374 meters per side
# Volume: 2788975.9999027364 cubic meters
#
# POW: 111
# Sectors per side: 66082292415
# Total sectors: 288572738700737828370869970573375
# Size: 176.1813106575 meters per side
# Volume: 5468642.1999802180 cubic meters
#
# POW: 112
# Sectors per side: 82711013889
# Total sectors: 565835294639989277437561941114369
# Size: 220.5149715640 meters per side
# Volume: 10722949.0368300509 cubic meters
#
# POW: 113
# Sectors per side: 103524129815
# Total sectors: 1109493509634246071423760541418375
# Size: 276.0046028813 meters per side
# Volume: 21025627.9047972448 cubic meters
#
# POW: 114
# Sectors per side: 129574586869
# Total sectors: 2175502058038082572436207843272909
# Size: 345.4574547615 meters per side
# Volume: 41227187.3438073099 cubic meters
#
# POW: 115
# Sectors per side: 162180291609
# Total sectors: 4265738522281416382050168931979529
# Size: 432.3871841348 meters per side
# Volume: 80838535.8993363976 cubic meters
#
# POW: 116
# Sectors per side: 202990784091
# Total sectors: 8364287716541458291432365135665571
# Size: 541.1916125421 meters per side
# Volume: 158508724.6473772824 cubic meters
#
# POW: 117
# Sectors per side: 254070688963
# Total sectors: 16400749515424223155544483288672347
# Size: 677.3752142261 meters per side
# Volume: 310804933.6717360616 cubic meters
#
# POW: 118
# Sectors per side: 318004165951
# Total sectors: 32158695849443655239313613275580351
# Size: 847.8275904830 meters per side
# Volume: 609428326.4954390526 cubic meters
#
# POW: 119
# Sectors per side: 398025643867
# Total sectors: 63056979058525517778047731183795363
# Size: 1061.1720182376 meters per side
# Volume: 1194971008.8184425831 cubic meters
#
# POW: 120
# Sectors per side: 498183452099
# Total sectors: 123642532849336113828340478328126299
# Size: 1328.2017062527 meters per side
# Volume: 2343106891.8589811325 cubic meters
#
# POW: 121
# Sectors per side: 623544627765
# Total sectors: 242439079032615319414767747510922125
# Size: 1662.4258293461 meters per side
# Volume: 4594379165.8609285355 cubic meters
#
# POW: 122
# Sectors per side: 780451259823
# Total sectors: 475376116027733265469631256968074767
# Size: 2080.7529647492 meters per side
# Volume: 9008688418.3052196503 cubic meters
#
# POW: 123
# Sectors per side: 976841338755
# Total sectors: 932120566500628182464750926170718875
# Size: 2604.3465061035 meters per side
# Volume: 17664294584.3926658630 cubic meters
#
# POW: 124
# Sectors per side: 1222650343749
# Total sectors: 1827708042543378251449453459943218749
# Size: 3259.6953308582 meters per side
# Volume: 34636263202.4686279297 cubic meters
#
# POW: 125
# Sectors per side: 1530313883905
# Total sectors: 3583781764751624022031922197448442625
# Size: 4079.9538867481 meters per side
# Volume: 67915009167.1157684326 cubic meters
#
# POW: 126
# Sectors per side: 1915396822359
# Total sectors: 7027102490342509682473311581162814279
# Size: 5106.6194930592 meters per side
# Volume: 133168189744.0954589844 cubic meters
#
# POW: 127
# Sectors per side: 2397380711033
# Total sectors: 13778788065537937536446209360361872937
# Size: 6391.6317122044 meters per side
# Volume: 261117048751.8816528320 cubic meters
#
# POW: 128
# Sectors per side: 3000649372781
# Total sectors: 27017536860525909099873562964971855541
# Size: 8000.0000000039 meters per side
# Volume: 512000000000.7459716797 cubic meters
#
# Smallest construct side length: 0.00 meters
